# %%
import pandas as pd

# %%
df=pd.read_csv(r"Data-cleaning-for-beginners-using-pandas-dataset.csv")
df
# Out:
#     Index   Age      Salary  Rating       Location  Established Easy Apply
# 0       0  44.0   $44k-$99k     5.4       India,In         1999       TRUE
# 1       1  66.0   $55k-$66k     3.5    New York,Ny         2002       TRUE
# 2       2   NaN   $77k-$89k    -1.0    New York,Ny           -1         -1
# 3       3  64.0   $44k-$99k     4.4       India In         1988         -1
# 4       4  25.0   $44k-$99k     6.4  Australia Aus         2002         -1
# 5       5  44.0   $77k-$89k     1.4       India,In         1999       TRUE
# 6       6  21.0   $44k-$99k     0.0    New York,Ny           -1         -1
# 7       7  44.0   $44k-$99k    -1.0  Australia Aus           -1         -1
# 8       8  35.0   $44k-$99k     5.4    New York,Ny           -1         -1
# 9       9  22.0   $44k-$99k     7.7       India,In           -1       TRUE
# 10     10  55.0   $10k-$49k     5.4       India,In         2008       TRUE
# ...

# %%
df.shape
# Out:
# (29, 7)

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# dtype: bool

# %%
df
# Out:
#     Index   Age      Salary  Rating       Location  Established Easy Apply
# 0       0  44.0   $44k-$99k     5.4       India,In         1999       TRUE
# 1       1  66.0   $55k-$66k     3.5    New York,Ny         2002       TRUE
# 2       2   NaN   $77k-$89k    -1.0    New York,Ny           -1         -1
# 3       3  64.0   $44k-$99k     4.4       India In         1988         -1
# 4       4  25.0   $44k-$99k     6.4  Australia Aus         2002         -1
# 5       5  44.0   $77k-$89k     1.4       India,In         1999       TRUE
# 6       6  21.0   $44k-$99k     0.0    New York,Ny           -1         -1
# 7       7  44.0   $44k-$99k    -1.0  Australia Aus           -1         -1
# 8       8  35.0   $44k-$99k     5.4    New York,Ny           -1         -1
# 9       9  22.0   $44k-$99k     7.7       India,In           -1       TRUE
# 10     10  55.0   $10k-$49k     5.4       India,In         2008       TRUE
# ...

# %%
df['Age']=df['Age'].fillna(df['Age'].mean(numeric_only=True)).astype(int)
df
# Out:
#     Index  Age      Salary  Rating       Location  Established Easy Apply
# 0       0   44   $44k-$99k     5.4       India,In         1999       TRUE
# 1       1   66   $55k-$66k     3.5    New York,Ny         2002       TRUE
# 2       2   39   $77k-$89k    -1.0    New York,Ny           -1         -1
# 3       3   64   $44k-$99k     4.4       India In         1988         -1
# 4       4   25   $44k-$99k     6.4  Australia Aus         2002         -1
# 5       5   44   $77k-$89k     1.4       India,In         1999       TRUE
# 6       6   21   $44k-$99k     0.0    New York,Ny           -1         -1
# 7       7   44   $44k-$99k    -1.0  Australia Aus           -1         -1
# 8       8   35   $44k-$99k     5.4    New York,Ny           -1         -1
# 9       9   22   $44k-$99k     7.7       India,In           -1       TRUE
# 10     10   55   $10k-$49k     5.4       India,In         2008       TRUE
# 11     11   44   $10k-$49k     6.7       India,In         2009         -1
# ...

# %%
df[['l_Salary', 'h_Salary']] = df['Salary'].str.split('-', expand=True)
df
# Out:
#     Index  Age      Salary  Rating       Location  Established Easy Apply  \
# 0       0   44   $44k-$99k     5.4       India,In         1999       TRUE
# 1       1   66   $55k-$66k     3.5    New York,Ny         2002       TRUE
# 2       2   39   $77k-$89k    -1.0    New York,Ny           -1         -1
# 3       3   64   $44k-$99k     4.4       India In         1988         -1
# 4       4   25   $44k-$99k     6.4  Australia Aus         2002         -1
# 5       5   44   $77k-$89k     1.4       India,In         1999       TRUE
# 6       6   21   $44k-$99k     0.0    New York,Ny           -1         -1
# 7       7   44   $44k-$99k    -1.0  Australia Aus           -1         -1
# 8       8   35   $44k-$99k     5.4    New York,Ny           -1         -1
# 9       9   22   $44k-$99k     7.7       India,In           -1       TRUE
# 10     10   55   $10k-$49k     5.4       India,In         2008       TRUE
# 11     11   44   $10k-$49k     6.7       India,In         2009         -1
# ...

# %%
#df['l_Salary']=df['l_Salary'].str.replace('k','')
#df['h_Salary']=df['h_Salary'].str.replace('k','')
#df['l_Salary']=df['l_Salary'].astype(int)
#df['h_Salary']=df['h_Salary'].astype(int)
#df['h_Salary'].info()
df
# Out:
#     Index  Age      Salary  Rating       Location  Established Easy Apply  \
# 0       0   44   $44k-$99k     5.4       India,In         1999       TRUE
# 1       1   66   $55k-$66k     3.5    New York,Ny         2002       TRUE
# 2       2   39   $77k-$89k    -1.0    New York,Ny           -1         -1
# 3       3   64   $44k-$99k     4.4       India In         1988         -1
# 4       4   25   $44k-$99k     6.4  Australia Aus         2002         -1
# 5       5   44   $77k-$89k     1.4       India,In         1999       TRUE
# 6       6   21   $44k-$99k     0.0    New York,Ny           -1         -1
# 7       7   44   $44k-$99k    -1.0  Australia Aus           -1         -1
# 8       8   35   $44k-$99k     5.4    New York,Ny           -1         -1
# 9       9   22   $44k-$99k     7.7       India,In           -1       TRUE
# 10     10   55   $10k-$49k     5.4       India,In         2008       TRUE
# 11     11   44   $10k-$49k     6.7       India,In         2009         -1
# ...

# %%
df['Avg_Salary'] = (df['l_Salary'].astype(int) + df['h_Salary'].astype(int)) / 2

df
# Out:
#     Index  Age      Salary  Rating       Location  Established Easy Apply  \
# 0       0   44   $44k-$99k     5.4       India,In         1999       TRUE
# 1       1   66   $55k-$66k     3.5    New York,Ny         2002       TRUE
# 2       2   39   $77k-$89k    -1.0    New York,Ny           -1         -1
# 3       3   64   $44k-$99k     4.4       India In         1988         -1
# 4       4   25   $44k-$99k     6.4  Australia Aus         2002         -1
# 5       5   44   $77k-$89k     1.4       India,In         1999       TRUE
# 6       6   21   $44k-$99k     0.0    New York,Ny           -1         -1
# 7       7   44   $44k-$99k    -1.0  Australia Aus           -1         -1
# 8       8   35   $44k-$99k     5.4    New York,Ny           -1         -1
# 9       9   22   $44k-$99k     7.7       India,In           -1       TRUE
# 10     10   55   $10k-$49k     5.4       India,In         2008       TRUE
# 11     11   44   $10k-$49k     6.7       India,In         2009         -1
# ...

# %%
#df=df.drop(columns=['Salary','l_Salary','h_Salary'])
df
# Out:
#     Index  Age  Rating       Location  Established Easy Apply  Avg_Salary
# 0       0   44     5.4       India,In         1999       TRUE        71.5
# 1       1   66     3.5    New York,Ny         2002       TRUE        60.5
# 2       2   39    -1.0    New York,Ny           -1         -1        83.0
# 3       3   64     4.4       India In         1988         -1        71.5
# 4       4   25     6.4  Australia Aus         2002         -1        71.5
# 5       5   44     1.4       India,In         1999       TRUE        83.0
# 6       6   21     0.0    New York,Ny           -1         -1        71.5
# 7       7   44    -1.0  Australia Aus           -1         -1        71.5
# 8       8   35     5.4    New York,Ny           -1         -1        71.5
# 9       9   22     7.7       India,In           -1       TRUE        71.5
# 10     10   55     5.4       India,In         2008       TRUE        29.5
# 11     11   44     6.7       India,In         2009         -1        29.5
# ...

# %%
df['Rating']=df['Rating'].apply(lambda x:x if x>=0 else 0)
df
# Out:
#     Index  Age  Rating       Location  Established Easy Apply  Avg_Salary
# 0       0   44     5.4       India,In         1999       TRUE        71.5
# 1       1   66     3.5    New York,Ny         2002       TRUE        60.5
# 2       2   39     0.0    New York,Ny           -1         -1        83.0
# 3       3   64     4.4       India In         1988         -1        71.5
# 4       4   25     6.4  Australia Aus         2002         -1        71.5
# 5       5   44     1.4       India,In         1999       TRUE        83.0
# 6       6   21     0.0    New York,Ny           -1         -1        71.5
# 7       7   44     0.0  Australia Aus           -1         -1        71.5
# 8       8   35     5.4    New York,Ny           -1         -1        71.5
# 9       9   22     7.7       India,In           -1       TRUE        71.5
# 10     10   55     5.4       India,In         2008       TRUE        29.5
# 11     11   44     6.7       India,In         2009         -1        29.5
# ...

# %%
df['Established']=df['Established'].apply(lambda x:x if x>=0 else 0)
df
# Out:
#     Index  Age  Rating       Location  Established Easy Apply  Avg_Salary
# 0       0   44     5.4       India,In         1999       TRUE        71.5
# 1       1   66     3.5    New York,Ny         2002       TRUE        60.5
# 2       2   39     0.0    New York,Ny            0         -1        83.0
# 3       3   64     4.4       India In         1988         -1        71.5
# 4       4   25     6.4  Australia Aus         2002         -1        71.5
# 5       5   44     1.4       India,In         1999       TRUE        83.0
# 6       6   21     0.0    New York,Ny            0         -1        71.5
# 7       7   44     0.0  Australia Aus            0         -1        71.5
# 8       8   35     5.4    New York,Ny            0         -1        71.5
# 9       9   22     7.7       India,In            0       TRUE        71.5
# 10     10   55     5.4       India,In         2008       TRUE        29.5
# 11     11   44     6.7       India,In         2009         -1        29.5
# ...

# %%
#df['Easy Apply']=df['Easy Apply'].apply(lambda x:'TRUE' if x=='TRUE' else 'FALSE')
df
# Out:
#     Index  Age  Rating       Location  Established Easy Apply  Avg_Salary
# 0       0   44     5.4       India,In         1999       TRUE        71.5
# 1       1   66     3.5    New York,Ny         2002       TRUE        60.5
# 2       2   39     0.0    New York,Ny            0      FALSE        83.0
# 3       3   64     4.4       India In         1988      FALSE        71.5
# 4       4   25     6.4  Australia Aus         2002      FALSE        71.5
# 5       5   44     1.4       India,In         1999       TRUE        83.0
# 6       6   21     0.0    New York,Ny            0      FALSE        71.5
# 7       7   44     0.0  Australia Aus            0      FALSE        71.5
# 8       8   35     5.4    New York,Ny            0      FALSE        71.5
# 9       9   22     7.7       India,In            0       TRUE        71.5
# 10     10   55     5.4       India,In         2008       TRUE        29.5
# 11     11   44     6.7       India,In         2009      FALSE        29.5
# ...
